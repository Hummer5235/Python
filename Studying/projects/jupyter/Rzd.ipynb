# %%
from selenium.webdriver import Firefox
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from time import sleep


# date = int(input('Введите дату: ')) 
# month = int(input('Введите месяц: '))
date = 12
month = 2
# city_from = input('Введите город отправления: ').capitalize()
# city_to = input('Введите город прибытия: ').capitalize()
city_from = 'Краснодар'
city_to = 'Москва'
trains = []

# %%
browser = Firefox()
browser.implicitly_wait(5)

# %%
browser.get('https://www.rzd.ru/')

# %%
coockie_button = browser.find_element(By.CLASS_NAME,'cookie-alert__btn')

# %%
if coockie_button:
    coockie_button.click()

# %%
browser.find_element(By.XPATH,'//input[@id="direction-from"]').send_keys(f'{city_from}')

# %%
browser.find_element(By.XPATH,f'//li[@aria-label="{city_from}"]').click()

# %%
browser.find_element(By.XPATH,'//input[@id="direction-to"]').send_keys(f'{city_to}')

# %%
browser.find_element(By.XPATH,f'//li[@aria-label="{city_to}"]').click()

# %%
browser.find_element(By.XPATH,f'//*[@id="datepicker-from"]').click()

# %%
browser.find_element(By.XPATH,f'//td[@data-day="{date}"][@data-month="{month-1}"]').click()
browser.find_element(By.XPATH,'//a[@aria-label="Найти маршруты"]').click()

# %%
# browser.find_element(By.CLASS_NAME,"icon-only--md").click()
# browser.find_element(By.CLASS_NAME,'header__label').click()

# %%
# browser.find_element(By.XPATH,f'//input[@aria-label="Изменить дату отправления."]').clear()
# browser.find_element(By.XPATH,f'//input[@aria-label="Изменить дату отправления."]').send_keys(f'{date}.0{month}.2024')

# browser.find_element(By.XPATH,'//*[@aria-label="Найти новый маршрут, при условии изменения поиска."]').click()
# sleep(3)
# soup = BeautifulSoup(browser.page_source,'lxml')
# card_list = soup.find('rzd-search-results-card-list',class_='ng-star-inserted').find_all('div',class_='container')

# %%
for i in range(10):
    sleep(3)
    browser.find_element(By.CLASS_NAME,"icon-only--md").click()
    browser.find_element(By.XPATH,f'//input[@aria-label="Изменить дату отправления."]').clear()
    browser.find_element(By.XPATH,f'//input[@aria-label="Изменить дату отправления."]').send_keys(f'{date}.0{month}.2024')
    browser.find_element(By.CLASS_NAME,'header__label').click()
    browser.find_element(By.XPATH,'//*[@aria-label="Найти новый маршрут, при условии изменения поиска."]').click()
    sleep(3)
    soup = BeautifulSoup(browser.page_source,'lxml')
    card_list = soup.find('rzd-search-results-card-list',class_='ng-star-inserted').find_all('div',class_='container')
    for number,value in enumerate(card_list):
        title = card_list[number].find('div',class_='fade-out__content').text
        dates = card_list[number].find_all('div',class_='card-route__date')
        dates  = [date.text for date in dates]
        start_date, end_date = dates
        times = card_list[number].find_all('div',class_='card-route__time')
        times = [element.text.strip() for element in times]
        start_time,end_time = times
        trains.append([title,start_date+start_time,end_date+end_time])
    date+=1

# %%
for train in trains:
    print(train)
# Out:
# [' 306С • ФПК • Сухум → Краснодар 1 → Москва Казанская  ', ' 12 февр., пн 01:59', ' 13 февр., вт 04:40']
# [' 092С  «ТАВРИЯ» • ГРАНДТ • Севастополь → Краснодар 1 → Москва Казанская  ', ' 12 февр., пн 10:44', ' 13 февр., вт 08:23']
# [' 266Э • ФПК • Новороссийск → Краснодар 1 → Москва Казанская  ', ' 12 февр., пн 20:08', ' 13 февр., вт 19:10']
# [' 110*С • ФПК • Анапа → Краснодар 1 → Москва Киевская  ', ' 12 февр., пн 21:30', ' 14 февр., ср 08:45']
# [' 092С  «ТАВРИЯ» • ГРАНДТ • Севастополь → Краснодар 1 → Москва Казанская  ', ' 19 февр., пн 10:44', ' 20 февр., вт 08:23']
# [' 114С • ФПК • Адлер → Краснодар 1 → Москва ВК Восточный  → Санкт-Петербург-Главный (Московский вокзал) ', ' 19 февр., пн 14:02', ' 21 февр., ср 01:01']
# [' 266Э • ФПК • Новороссийск → Краснодар 1 → Москва Казанская  ', ' 19 февр., пн 20:02', ' 20 февр., вт 19:10']
# [' 084С • ФПК • Адлер → Краснодар 1 → Москва Киевская  ', ' 19 февр., пн 21:22', ' 21 февр., ср 09:30']
# [' 138С • ФПК • Имеретинский Курорт (Олимпийский парк) → Краснодар 1 → Москва Казанская  → Нижний Новгород Московский (Московский вокзал) ', ' 19 февр., пн 23:16', ' 21 февр., ср 00:20']
# [' 104Ж  «Двухэтажный состав» • ФПК • Адлер → Краснодар 1 → Москва Казанская  ', ' 19 февр., пн 23:40', ' 20 февр., вт 18:25']
# [' 030Й  «Премиум» • ФПК • Новороссийск → Краснодар 1 → Москва Казанская  ', ' 19 февр., пн 23:48', ' 20 февр., вт 19:00']
# [' 306С • ФПК • Сухум → Краснодар 1 → Москва Казанская  ', ' 20 февр., вт 01:59', ' 21 февр., ср 04:40']
# [' 092С  «ТАВРИЯ» • ГРАНДТ • Севастополь → Краснодар 1 → Москва Казанская  ', ' 20 февр., вт 10:44', ' 21 февр., ср 08:23']
# [' 266Э • ФПК • Новороссийск → Краснодар 1 → Москва Казанская  ', ' 20 февр., вт 20:02', ' 21 февр., ср 19:10']
# [' 084Э • ФПК • Адлер → Краснодар 1 → Москва Киевская  ', ' 20 февр., вт 21:22', ' 22 февр., чт 09:30']
# [' 110*С • ФПК • Анапа → Краснодар 1 → Москва Киевская  ', ' 20 февр., вт 21:30', ' 22 февр., чт 08:45']
# [' 104Ж  «Двухэтажный состав» • ФПК • Адлер → Краснодар 1 → Москва Казанская  ', ' 20 февр., вт 23:40', ' 21 февр., ср 18:25']
# [' 030Й  «Премиум» • ФПК • Новороссийск → Краснодар 1 → Москва Казанская  ', ' 20 февр., вт 23:48', ' 21 февр., ср 19:00']
# [' 092С  «ТАВРИЯ» • ГРАНДТ • Севастополь → Краснодар 1 → Москва Казанская  ', ' 21 февр., ср 10:44', ' 22 февр., чт 08:23']
# [' 114С • ФПК • Адлер → Краснодар 1 → Москва ВК Восточный  → Санкт-Петербург-Главный (Московский вокзал) ', ' 21 февр., ср 14:02', ' 23 февр., пт 01:01']
# [' 266Э • ФПК • Новороссийск → Краснодар 1 → Москва Казанская  ', ' 21 февр., ср 20:02', ' 22 февр., чт 19:10']
# [' 084С • ФПК • Адлер → Краснодар 1 → Москва Киевская  ', ' 21 февр., ср 21:22', ' 23 февр., пт 09:30']
# [' 138С • ФПК • Имеретинский Курорт (Олимпийский парк) → Краснодар 1 → Москва Казанская  → Нижний Новгород Московский (Московский вокзал) ', ' 21 февр., ср 23:16', ' 23 февр., пт 00:20']
# [' 104Ж  «Двухэтажный состав» • ФПК • Адлер → Краснодар 1 → Москва Казанская  ', ' 21 февр., ср 23:40', ' 22 февр., чт 18:25']
# [' 030Й  «Премиум» • ФПК • Новороссийск → Краснодар 1 → Москва Казанская  ', ' 21 февр., ср 23:48', ' 22 февр., чт 19:00']
